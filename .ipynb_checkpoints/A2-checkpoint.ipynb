# %%
#This program is written in python 3.5.1
#What is yours?!

import sys
sys.version
# Out:
# '3.5.1 (v3.5.1:37a07cee5969, Dec  5 2015, 21:12:44) \n[GCC 4.2.1 (Apple Inc. build 5666) (dot 3)]'

# %%
path="/Users/mgorjise/Documents/new/reading/CMU/Model elements and connections April 2016.xlsx"
path="/Users/mgorjise/Documents/new/reading/CMU/New.xlsx"
import pandas as pd
xl = pd.ExcelFile(path)
xl.sheet_names
# Out:
# ['Sheet1']

# %%
df = xl.parse('Sheet1')
df.head()
# Out:
#                                       Full element name  \
# NaN                                                 NaN
# NaN                                                 NaN
#  1.0  Disintegrin and metalloproteinase domain-conta...
#  2.0    RAC-alpha serine/threonine-protein kinase (Akt)
#  3.0             5' AMP-activated protein kinase (AMPK)
#
#      Executable model variable name Element values Unnamed: 3     Unnamed: 4  \
# NaN                             NaN    Sc. 1 Begin  Sc. 1 End  Sc. 1 Sim End
# NaN                             NaN            NaN        NaN            NaN
#  1.0                         ADAM17              0          1              0
#  2.0                           AKT1              0          1              2
#  3.0                           AMPK              0          1              0
#
#        Unnamed: 5 Unnamed: 6     Unnamed: 7   Unnamed: 8 Unnamed: 9  \
# NaN   Sc. 2 Begin  Sc. 2 End  Sc. 2 Sim End  Sc. 3 Begin  Sc. 3 End
# NaN           NaN        NaN            NaN          NaN        NaN
#  1.0            2          1              2            1          0
#  2.0            1          2              0            2          2
#  3.0            1          2              1            2          2
#
#          ...     Direct downstream connections in the model  Unnamed: 31  \
# NaN      ...                                       Positive     Negative
# NaN      ...                                            NaN          NaN
#  1.0     ...                                   EGFex,TNFaex          NaN
#  2.0     ...                            mTOR,MDM2cyto,BclXL          NaN
#  3.0     ...                                           TSC2          NaN
#
#      Unnamed: 32                   Unnamed: 33            Unnamed: 34  \
# NaN          NaN  References for Influence set                    NaN
# NaN          NaN                           NaN                    NaN
#  1.0         NaN                  PMID24096196                    NaN
#  2.0         NaN                    PMC3128635  PMC4295631 index card
#  3.0         NaN                    PMC3454471                    NaN
#
#      Unnamed: 35 Unnamed: 36 Unnamed: 37 Unnamed: 38 Unnamed: 39
# NaN          NaN         NaN         NaN         NaN         NaN
# NaN          NaN         NaN         NaN         NaN         NaN
#  1.0         NaN         NaN         NaN         NaN         NaN
#  2.0         NaN         NaN         NaN         NaN         NaN
#  3.0         NaN         NaN         NaN         NaN         NaN
#
# [5 rows x 40 columns]

# %%
df.columns
# Out:
# Index(['Full element name', 'Executable model variable name', 'Element values',
#        'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 'Unnamed: 6', 'Unnamed: 7',
#        'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10', 'Importance of element',
#        'Graph model variable name', 'Unique ID', 'Unique ID (text)',
#        'Element kind', 'Element type', 'Element sub-type',
#        'Spontaneously Restores (R) Degrades (D)',
#        'Type of value: Activity (A) Amount (C) Process (P)', 'Location',
#        'Model   Input (I) Output (O)', 'initial value', 'Unnamed: 23',
#        'No. of reg.', 'Interaction', 'Unnamed: 26', 'Influence set',
#        'Unnamed: 28', 'Unnamed: 29',
#        'Direct downstream connections in the model', 'Unnamed: 31',
#        'Unnamed: 32', 'Unnamed: 33', 'Unnamed: 34', 'Unnamed: 35',
#        'Unnamed: 36', 'Unnamed: 37', 'Unnamed: 38', 'Unnamed: 39'],
#       dtype='object')

# %%
df=df[1:157]
participant=list(df['Graph model variable name'])
location=list(df['Location'])
uniqueid=list(df['Unique ID'])
ElementType=list(df['Element type'])

# %%
uniqueid
# Out:
# ['P78536',
#  'P31749',
#  'Q13131',
#  'P05412',
#  'ARE',
#  'Q9UBU7',
#  'Q8WYN0',
#  'chebi',
#  'Q13315',
#  'HMDB00538',
#  'O14867',
#  'Q07817',
#  'Q14790',
#  'O96017',
#  'Q13490',
#  'P01584',
#  'P01584',
#  'Q9UII6',
#  'Q01094',
#  'P01133',
#  'P01133',
#  'P01133',
#  'P00533',
#  'P00533',
#  'P00533',
#  'P00533',
#  'P27361',
#  'P27361',
#  'Q9NV70',
#  'GO:0070062',
#  'P05230',
#  'P11362',
#  'P11362',
#  'P02751',
#  'P02751',
#  'P02751',
#  'GO:0051894',
#  'P01100',
#  'HMDB00125',
#  'P08263',
#  'P08263',
#  'P08263',
#  'Q16665',
#  'Q16665',
#  'Q16665',
#  'Q16665',
#  'HRE',
#  'P09429',
#  'O60725',
#  'P01579',
#  'P15260',
#  'P15260',
#  'P05019',
#  'P08069',
#  'P08069',
#  'P10145',
#  'P08648',
#  'P23458',
#  'P45983',
#  'P45983',
#  'HMDB00190',
#  'Q15831',
#  'Q14766',
#  'Q00987',
#  'Q00987',
#  'Q00987',
#  'Q00987',
#  'Q02750',
#  'O60934',
#  'P42345',
#  'HMDB00221',
#  'P19838',
#  'P19838',
#  'Q9Y5S8',
#  'Q16236',
#  'Q16236',
#  'P38936',
#  'P38936',
#  'Q16539',
#  'P04637',
#  'P04637',
#  'P04085',
#  'P04085',
#  'P04085',
#  'P16234',
#  'P16234',
#  'Q15118',
#  'P32119',
#  'P42336',
#  'HMDB10147',
#  'P17252',
#  'P67775',
#  'P60484',
#  'P63000',
#  'P04049',
#  'Q15109',
#  'Q15109',
#  'P01116',
#  'P06400',
#  'P27695',
#  'P27695',
#  'P08134',
#  'Q13546',
#  'ChemIDPlus: D017382000',
#  'HMDB03125',
#  'HMDB01377',
#  'HMDB02168',
#  'Q15418',
#  'P84022',
#  'P84022',
#  'P00441',
#  'P00441',
#  'P00441',
#  'P12931',
#  'P42224',
#  'P42224',
#  'P01137',
#  'P36897',
#  'P36897',
#  'Q9NQ88',
#  'Q9NQ88',
#  'Q9NQ88',
#  'P01375',
#  'P01375',
#  'P01375',
#  'P19438',
#  'P19438',
#  'P19438',
#  'P19438',
#  'Q12933',
#  'Q12933',
#  'Q12933',
#  'P09758',
#  'P49815',
#  'P10599',
#  'P15692',
#  'P15692',
#  'P15692',
#  'P17948',
#  'P17948',
#  'P04628',
#  'AcidicME',
#  'GO:0006915',
#  'GO:0006914',
#  'GO:0044291',
#  'GO:0008219',
#  'GO:15680329',
#  'GO:1990166',
#  'GO:0090592',
#  'GO:0006096',
#  'GO:0016049',
#  'GO:0050663',
#  'GO:0097528',
#  'GO:0006119',
#  'GO:0006098',
#  'GO:0008283',
#  'GO:0006099']
